# %%
import pyttsx3 
from sklearn.neighbors import KNeighborsClassifier
from keras.utils import to_categorical
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import pandas as pd

# %%
df= pd.read_csv(r"C:\Users\Shourya\OneDrive\coding\dataset\dataset .csv") 
df.head(11)
# Out:
#     Disease  Symptom_1  Symptom_2  Symptom_3
# 0         1          1          7         14
# 1         2          2          8         15
# 2         3          3          9         16
# 3         4          1         10         14
# 4         5          1         10         14
# 5         6          1         11         17
# 6         7          3         10         15
# 7         8          1         10         18
# 8         9          4         12         19
# 9        10          5         10         20
# 10       11          6         13         19

# %%
df.dtypes
# Out:
# Disease      int64
# Symptom_1    int64
# Symptom_2    int64
# Symptom_3    int64
# dtype: object

# %%
engine = pyttsx3.init('sapi5')
voices = engine.getProperty('voices')
engine.setProperty('voice',voices[1].id)

def speak(audio):
    engine.say(audio)
    engine.runAndWait()

# %%
speak("hello my name is proxy. i am your fitness advisor")
speak("enter your username")
x = input("enter your username : ")
speak("enter your password")
y = input("enter your password : ")
if x == "marvel" and y == "xyz" :
    print("access granted")
    speak("access granted")
    print("how much is your weight")    
    speak("how much is your weight")
    weight = float(input("kilograms : "))
    print("how much is your height")
    speak("how much is your height")
    height = float(input("metres : "))    
    s = weight/(height*height)
    print(s)

    if s>18.5 and s<24.9:
        print("you're in the healthy weight range.") 
        speak("you're in the healthy weight range.") 
        print("Limit portion size to control calorie intake. Add healthy snacks during the day if you want to   gain weight. Be as physically active as you can be. Talk to your doctor about your weight if you think that you weigh too much or too little.")
        speak("Limit portion size to control calorie intake. Add healthy snacks during the day if you want to gain weight. Be as physically active as you can be. Talk to your doctor about your weight if you think that you weigh too much or too little.")
    elif s<18.5 :
            print("you're in the underweight range.")
            speak("you're in the underweight range.")
            print ("If you are underweight, it's important to eat a variety of foods that give you the nutrition you need. You should make sure you eat enough energy to gain weight, protein to repair your body and build your muscles, and vitamins and minerals to make you healthy.")
            speak ("If you are underweight, it's important to eat a variety of foods that give you the nutrition you need. You should make sure you eat enough energy to gain weight, protein to repair your body and build your muscles, and vitamins and minerals to make you healthy.")     


    elif s>24.9 and s<29.9:
            print("you're in the overweight range.")    
            speak("you're in the overweight range.")        
            print("Diet. A steady weight loss of about one pound a week is the safest way to lose weight. Your doctor can refer you to a registered dietitian if you need help in planning your diet Regular exercise such as brisk walking, running, swimming, biking, dancing. The amount of exercise needed to lose weight is different for everyone")    
            speak("Diet. A steady weight loss of about one pound a week is the safest way to lose weight. Your doctor can refer you to a registered dietitian if you need help in planning your diet Regular exercise such as brisk walking, running, swimming, biking, dancing. The amount of exercise needed to lose weight is different for everyone")  
           
            print("since, you are overweight so there is a possibillity that you may be suffering from a disease")
            speak("since, you are overweight so there is a possibillity that you may be suffering from a disease")
            

            print("chose one of these which you are facing. for fatigue write 1, for mucoid sputum write 2, for  chest pain write 3, for muscle weakness write 4, for sunken eyes write 5, for joint pain write 6") 
            speak("chose one of these which you are facing. for fatigue write 1, for mucoid sputum write 2, for  chest pain write 3, for muscle weakness write 4, for sunken eyes write 5, for joint pain write 6")             
            x_1 = input("enter:")
            print("chose one of these which you are facing. for restlessness write 7, for family history write 8, for dizziness write 9, for vomiting write 10, for weight gain write 11, for stiff neck write 12, for neck pain write 13")
            speak("chose one of these which you are facing. for restlessness write 7, for family history write 8, for dizziness write 9, for vomiting write 10, for weight gain write 11, for stiff neck write 12, for neck pain write 13")   
            x_2 = input("enter:")
            print("chose one of these which you are facing. for weight loss write 14, for breathlessness write 15, for lack of concentration write 16 , for cold hands and feets write 17, for anxiety write 18, for swelling joints write 19, for dehydration write 20")
            speak("chose one of these which you are facing. for weight loss write 14, for breathlessness write 15, for lack of concentration write 16 , for cold hands and feets write 17, for anxiety write 18, for swelling joints write 19, for dehydration write 20")
            x_3 = input("enter:")
            
             
         
            KNN = KNeighborsClassifier()

 
            x2 = df[['Symptom_1','Symptom_2','Symptom_3']]
            y2 = df['Disease']

  
# Train KNN using the x and y values. This is done through the .fit method.
            KNN = KNN.fit(x2,y2)

# Let us use the trained KNN to predict the type of flower if its sepal length = 5 and sepal_width = 3 We can use the .predict method to do so.
            test = pd.DataFrame()
            test['Symptom_1'] = [x_1]
            test['Symptom_2'] = [x_2]
            test['Symptom_3'] = [x_3]
            
            
            
            predict_disease = KNN.predict(test)

            if predict_disease == [1]:
                print("the disease you are suffering with is diabetes")
                speak("the disease you are suffering with is diabetes") 
                print("Diabetes is a disease that occurs when your blood glucose, also called blood sugar, is too high. Blood glucose is your main source of energy and comes from the food you eat. Insulin, a hormone made by the pancreas, helps glucose from food get into your cells to be used for energy.")
                speak("Diabetes is a disease that occurs when your blood glucose, also called blood sugar, is too high. Blood glucose is your main source of energy and comes from the food you eat. Insulin, a hormone made by the pancreas, helps glucose from food get into your cells to be used for energy.")
                print("the precautions to diabetes is to have balanced diet, exercise, consulting doctor and follow up")
                speak("the precautions to diabetes is to have balanced diet, exercise, consulting doctor and follow up")

            elif predict_disease == [2]:
                print("the disease you are suffering with is Bronchial Asthma")
                speak("the disease you are suffering with is Bronchial Asthma")
                print("Bronchial asthma is a medical condition which causes the airway path of the lungs to swell and narrow. Due to this swelling, the air path produces excess mucus making it hard to breathe, which results in coughing, short breath, and wheezing. The disease is chronic and interferes with daily working.")
                speak("Bronchial asthma is a medical condition which causes the airway path of the lungs to swell and narrow. Due to this swelling, the air path produces excess mucus making it hard to breathe, which results in coughing, short breath, and wheezing. The disease is chronic and interferes with daily working.")
                print("the precautions to Bronchial Asthma is to switch to loose cloothing,	take deep breaths, get away from trigger, seeking help")
                speak("the precautions to Bronchial Asthma is to switch to loose cloothing,	take deep breaths, get away from trigger and seeking help")

            elif predict_disease == [3]:    
                print("the disease you are suffering with is Hypertension")
                speak("the disease you are suffering with is Hypertension")
                print("Hypertension (HTN or HT), also known as high blood pressure (HBP), is a long-term medical condition in which the blood pressure in the arteries is persistently elevated. High blood pressure typically does not cause symptoms.")
                speak("Hypertension (HTN or HT), also known as high blood pressure (HBP), is a long-term medical condition in which the blood pressure in the arteries is persistently elevated. High blood pressure typically does not cause symptoms.")
                print("the precautions to hypertension is meditation, salt baths, reduce stress and	get proper sleep")
                speak("the precautions to hypertension is meditation, salt baths, reduce stress and	get proper sleep")
            elif predict_disease == [4]:
                print("the disease you are suffering with is Jaundice")
                speak("the disease you are suffering with is Jaundice")
                print("Yellow staining of the skin and sclerae (the whites of the eyes) by abnormally high blood levels of the bile pigment bilirubin. The yellowing extends to other tissues and body fluids. Jaundice was once called the morbus regius (the regal disease) in the belief that only the touch of a king could cure it")
                speak("Yellow staining of the skin and sclerae (the whites of the eyes) by abnormally high blood levels of the bile pigment bilirubin. The yellowing extends to other tissues and body fluids. Jaundice was once called the morbus regius (the regal disease) in the belief that only the touch of a king could cure it")
                print("the precautions to Jaundice is to drink plenty of water, consume milk thistle, eat fruits and high fiberous food,	medication")
            elif predict_disease == [5]:
                print("the disease you are suffering with is Tuberculosis")
                speak("the disease you are suffering with is Tuberculosis")
                print("Tuberculosis (TB) is an infectious disease usually caused by Mycobacterium tuberculosis (MTB) bacteria. Tuberculosis generally affects the lungs, but can also affect other parts of the body. Most infections show no symptoms, in which case it is known as latent tuberculosis.")
                speak("Tuberculosis (TB) is an infectious disease usually caused by Mycobacterium tuberculosis (MTB) bacteria. Tuberculosis generally affects the lungs, but can also affect other parts of the body. Most infections show no symptoms, in which case it is known as latent tuberculosis.")
                print("the precautions to Tuberculosis is to cover mouth, consult doctor, medication, rest")
                speak ("the precautions to Tuberculosis is to cover mouth, consult doctor, medication, rest")
            elif predict_disease == [6]:
                print("the disease you are suffering with is Hypothyroidism")
                speak("the disease you are suffering with is Hypothyroidism")
                print("Hypothyroidism, also called underactive thyroid or low thyroid, is a disorder of the endocrine system in which the thyroid gland does not produce enough thyroid hormone.")
                speak("Hypothyroidism, also called underactive thyroid or low thyroid, is a disorder of the endocrine system in which the thyroid gland does not produce enough thyroid hormone.")
                print("the precautions to Hypothyroidism is to reduce stress, exercise,	eat healthy	get proper sleep")
            elif predict_disease == [7]:
                print("the disease you are suffering with is Heart attack")
                speak("the disease you are suffering with is Heart attack")
                print("The death of heart muscle due to the loss of blood supply. The loss of blood supply is usually caused by a complete blockage of a coronary artery, one of the arteries that supplies blood to the heart muscle.")
                speak("The death of heart muscle due to the loss of blood supply. The loss of blood supply is usually caused by a complete blockage of a coronary artery, one of the arteries that supplies blood to the heart muscle.")
                print("the precautions to Heart attack is to call ambulance, chew or swallow asprin, keep calm")
                speak("the precautions to Heart attack is to call ambulance, chew or swallow asprin, keep calm")
            elif predict_disease == [8]:
                print("the disease you are suffering with is Hypoglycemia")
                speak("the disease you are suffering with is Hypoglycemia")
                print(" Hypoglycemia is a condition in which your blood sugar (glucose) level is lower than normal. Glucose is your body's main energy source. Hypoglycemia is often related to diabetes treatment. But other drugs and a variety of conditions â€” many rare â€” can cause low blood sugar in people who don't have diabetes.")
                speak(" Hypoglycemia is a condition in which your blood sugar (glucose) level is lower than normal. Glucose is your body's main energy source. Hypoglycemia is often related to diabetes treatment. But other drugs and a variety of conditions â€” many rare â€” can cause low blood sugar in people who don't have diabetes.")
                print("the precautions to Hypoglycemia is to lie down on side, check in pulse, drink sugary drinks,	consult doctor")
                speak("the precautions to Hypoglycemia is to lie down on side, check in pulse, drink sugary drinks,	consult doctor")

            elif predict_disease == [9]:
                print("the disease you are suffering with is Arthritis")
                speak("the disease you are suffering with is Arthritis")
                print("Arthritis is the swelling and tenderness of one or more of your joints. The main symptoms of arthritis are joint pain and stiffness, which typically worsen with age. The most common types of arthritis are osteoarthritis and rheumatoid arthritis.")
                speak("Arthritis is the swelling and tenderness of one or more of your joints. The main symptoms of arthritis are joint pain and stiffness, which typically worsen with age. The most common types of arthritis are osteoarthritis and rheumatoid arthritis.")
                print("the precautions to Arthritis is to exercise, use hot and cold therapy, try acupuncture,massage")
                speak("the precautions to Arthritis is to exercise, use hot and cold therapy, try acupuncture,massage")

            elif predict_disease == [10]:
                print("the disease you are suffering with is Gastroenteritis")
                speak("the disease you are suffering with is Gastroenteritis")
                print("Gastroenteritis is an inflammation of the digestive tract, particularly the stomach, and large and small intestines. Viral and bacterial gastroenteritis are intestinal infections associated with symptoms of diarrhea , abdominal cramps, nausea , and vomiting .")
                speak("Gastroenteritis is an inflammation of the digestive tract, particularly the stomach, and large and small intestines. Viral and bacterial gastroenteritis are intestinal infections associated with symptoms of diarrhea , abdominal cramps, nausea , and vomiting .")
                print("the precautions to Gastroenteritis is to stop eating solid food for while, try taking small sips of water, rest, ease back into eating")
                speak("the precautions to Gastroenteritis is to stop eating solid food for while, try taking small sips of water, rest, ease back into eating") 

            elif predict_disease == [11]:
                print("the disease you are suffering with is Osteoarthristis")
                speak("the disease you are suffering with is Osteoarthristis")
                print("Osteoarthritis is the most common form of arthritis, affecting millions of people worldwide. It occurs when the protective cartilage that cushions the ends of your bones wears down over time.")
                speak("Osteoarthritis is the most common form of arthritis, affecting millions of people worldwide. It occurs when the protective cartilage that cushions the ends of your bones wears down over time.")
                print("the precautions to Osteoarthristis is to acetaminophen, consult nearest hospital	follow up, salt baths")
                speak("the precautions to Osteoarthristis is to acetaminophen, consult nearest hospital	follow up, salt baths")
    elif s>30.0:
             print("you're in the obese range.")    
             speak("you're in the obese range.")
             print("People with obesity need to get at least 150 minutes a week of moderate-intensity physical activity to prevent further weight gain or to maintain the loss of a modest amount of weight. While the A.H.A mentions activities like climbing stairs and jogging, one of the easiest and most effective ways to ease into a healthier lifestyle is to begin walking.") 
             speak("People with obesity need to get at least 150 minutes a week of moderate-intensity physical activity to prevent further weight gain or to maintain the loss of a modest amount of weight. While the A.H.A mentions activities like climbing stairs and jogging, one of the easiest and most effective ways to ease into a healthier lifestyle is to begin walking.")
             
             print("since, you are obese so there is a possibillity that you may be suffering from a disease")
             speak("since, you are obese so there is a possibillity that you may be suffering from a disease")
            
             print("chose one of these which you are facing. for fatigue write 1, for mucoid sputum write 2, for  chest pain write 3, for muscle weakness write 4, for sunken eyes write 5, for joint pain write 6") 
             speak("chose one of these which you are facing. for fatigue write 1, for mucoid sputum write 2, for  chest pain write 3, for muscle weakness write 4, for sunken eyes write 5, for joint pain write 6") 
             
             x_1 = input("enter:")
             print("chose one of these which you are facing. for restlessness write 7, for family history write 8, for dizziness write 9, for vomiting write 10, for weight gain write 11, for stiff neck write 12, for neck pain write 13")   
             speak("chose one of these which you are facing. for restlessness write 7, for family history write 8, for dizziness write 9, for vomiting write 10, for weight gain write 11, for stiff neck write 12, for neck pain write 13")   
              
             x_2 = input("enter:")
             print("chose one of these which you are facing. for weight loss write 14, for breathlessness write 15, for lack of concentration write 16 , for cold hands and feets write 17, for anxiety write 18, for swelling joints write 19, for dehydration write 20")
             speak("chose one of these which you are facing. for weight loss write 14, for breathlessness write 15, for lack of concentration write 16 , for cold hands and feets write 17, for anxiety write 18, for swelling joints write 19, for dehydration write 20")
             x_3 = input("enter:")
            
             
         
             KNN = KNeighborsClassifier()

 
             x2 = df[['Symptom_1','Symptom_2','Symptom_3']]
             y2 = df['Disease']

  
# Train KNN using the x and y values. This is done through the .fit method.
             KNN = KNN.fit(x2,y2)

# Let us use the trained KNN to predict the type of flower if its sepal length = 5 and sepal_width = 3 We can use the .predict method to do so.
             test = pd.DataFrame()
             test['Symptom_1'] = [x_1]
             test['Symptom_2'] = [x_2]
             test['Symptom_3'] = [x_3]
            
            
            
             predict_disease = KNN.predict(test)

             if predict_disease == [1]:
                print("the disease you are suffering with is diabetes")
                speak("the disease you are suffering with is diabetes") 
                print("Diabetes is a disease that occurs when your blood glucose, also called blood sugar, is too high. Blood glucose is your main source of energy and comes from the food you eat. Insulin, a hormone made by the pancreas, helps glucose from food get into your cells to be used for energy.")
                speak("Diabetes is a disease that occurs when your blood glucose, also called blood sugar, is too high. Blood glucose is your main source of energy and comes from the food you eat. Insulin, a hormone made by the pancreas, helps glucose from food get into your cells to be used for energy.")
                print("the precautions to diabetes is to have balanced diet, exercise, consulting doctor and follow up")     
                speak("the precautions to diabetes is to have balanced diet, exercise, consulting doctor and follow up")

             elif predict_disease == [2]:
                 print("the disease you are suffering with is Bronchial Asthma")
                 speak("the disease you are suffering with is Bronchial Asthma")
                 print("Bronchial asthma is a medical condition which causes the airway path of the lungs to swell and narrow. Due to this swelling, the air path produces excess mucus making it hard to breathe, which results in coughing, short breath, and wheezing. The disease is chronic and interferes with daily working.")
                 speak("Bronchial asthma is a medical condition which causes the airway path of the lungs to swell and narrow. Due to this swelling, the air path produces excess mucus making it hard to breathe, which results in coughing, short breath, and wheezing. The disease is chronic and interferes with daily working.")
                 print("the precautions to Bronchial Asthma is to switch to loose cloothing,	take deep breaths, get away from trigger, seeking help")
                 speak("the precautions to Bronchial Asthma is to switch to loose cloothing,	take deep breaths, get away from trigger and seeking help")

             elif predict_disease == [3]:    
                 print("the disease you are suffering with is Hypertension")
                 speak("the disease you are suffering with is Hypertension")
                 print("Hypertension (HTN or HT), also known as high blood pressure (HBP), is a long-term medical condition in which the blood pressure in the arteries is persistently elevated. High blood pressure typically does not cause symptoms.")
                 speak("Hypertension (HTN or HT), also known as high blood pressure (HBP), is a long-term medical condition in which the blood pressure in the arteries is persistently elevated. High blood pressure typically does not cause symptoms.")
                 print("the precautions to hypertension is meditation, salt baths, reduce stress and	get proper sleep")
                 speak("the precautions to hypertension is meditation, salt baths, reduce stress and	get proper sleep")
             elif predict_disease == [4]:
                 print("the disease you are suffering with is Jaundice")
                 speak("the disease you are suffering with is Jaundice")
                 print("Yellow staining of the skin and sclerae (the whites of the eyes) by abnormally high blood levels of the bile pigment bilirubin. The yellowing extends to other tissues and body fluids. Jaundice was once called the morbus regius (the regal disease) in the belief that only the touch of a king could cure it")
                 speak("Yellow staining of the skin and sclerae (the whites of the eyes) by abnormally high blood levels of the bile pigment bilirubin. The yellowing extends to other tissues and body fluids. Jaundice was once called the morbus regius (the regal disease) in the belief that only the touch of a king could cure it")
                 print("the precautions to Jaundice is to drink plenty of water, consume milk thistle, eat fruits and high fiberous food,	medication")
             elif predict_disease == [5]:
                 print("the disease you are suffering with is Tuberculosis")
                 speak("the disease you are suffering with is Tuberculosis")
                 print("Tuberculosis (TB) is an infectious disease usually caused by Mycobacterium tuberculosis (MTB) bacteria. Tuberculosis generally affects the lungs, but can also affect other parts of the body. Most infections show no symptoms, in which case it is known as latent tuberculosis.")
                 speak("Tuberculosis (TB) is an infectious disease usually caused by Mycobacterium tuberculosis (MTB) bacteria. Tuberculosis generally affects the lungs, but can also affect other parts of the body. Most infections show no symptoms, in which case it is known as latent tuberculosis.")
                 print("the precautions to Tuberculosis is to cover mouth, consult doctor, medication, rest")
                 speak ("the precautions to Tuberculosis is to cover mouth, consult doctor, medication, rest")
             elif predict_disease == [6]:
                 print("the disease you are suffering with is Hypothyroidism")
                 speak("the disease you are suffering with is Hypothyroidism")
                 print("Hypothyroidism, also called underactive thyroid or low thyroid, is a disorder of the endocrine system by which the thyroid gland does not produce enough thyroid hormone.")
                 speak("Hypothyroidism, also called underactive thyroid or low thyroid, is a disorder of the endocrine system in which the thyroid gland does not produce enough thyroid hormone.")
                 print("the precautions to Hypothyroidism is to reduce stress, exercise,	eat healthy	get proper sleep")
             elif predict_disease == [7]:
                 print("the disease you are suffering with is Heart attack")
                 speak("the disease you are suffering with is Heart attack")
                 print("The death of heart muscle due to the loss of blood supply. The loss of blood supply is usually caused by a complete blockage of a coronary artery, one of the arteries that supplies blood to the heart muscle.")
                 speak("The death of heart muscle due to the loss of blood supply. The loss of blood supply is usually caused by a complete blockage of a coronary artery, one of the arteries that supplies blood to the heart muscle.")
                 print("the precautions to Heart attack is to call ambulance, chew or swallow asprin, keep calm")
                 speak("the precautions to Heart attack is to call ambulance, chew or swallow asprin, keep calm")
             elif predict_disease == [8]:
                 print("the disease you are suffering with is Hypoglycemia")
                 speak("the disease you are suffering with is Hypoglycemia")
                 print(" Hypoglycemia is a condition in which your blood sugar (glucose) level is lower than normal. Glucose is your body's main energy source. Hypoglycemia is often related to diabetes treatment. But other drugs and a variety of conditions â€” many rare â€” can cause low blood sugar in people who don't have diabetes.")
                 speak(" Hypoglycemia is a condition in which your blood sugar (glucose) level is lower than normal. Glucose is your body's main energy source. Hypoglycemia is often related to diabetes treatment. But other drugs and a variety of conditions â€” many rare â€” can cause low blood sugar in people who don't have diabetes.")
                 print("the precautions to Hypoglycemia is to lie down on side, check in pulse, drink sugary drinks,	consult doctor")
                 speak("the precautions to Hypoglycemia is to lie down on side, check in pulse, drink sugary drinks,	consult doctor")

             elif predict_disease == [9]:
                 print("the disease you are suffering with is Arthritis")
                 speak("the disease you are suffering with is Arthritis")
                 print("Arthritis is the swelling and tenderness of one or more of your joints. The main symptoms of arthritis are joint pain and stiffness, which typically worsen with age. The most common types of arthritis are osteoarthritis and rheumatoid arthritis.")
                 speak("Arthritis is the swelling and tenderness of one or more of your joints. The main symptoms of arthritis are joint pain and stiffness, which typically worsen with age. The most common types of arthritis are osteoarthritis and rheumatoid arthritis.")
                 print("the precautions to Arthritis is to exercise, use hot and cold therapy, try acupuncture,massage")
                 speak("the precautions to Arthritis is to exercise, use hot and cold therapy, try acupuncture,massage")

             elif predict_disease == [10]:
                 print("the disease you are suffering with is Gastroenteritis")
                 speak("the disease you are suffering with is Gastroenteritis")
                 print("Gastroenteritis is an inflammation of the digestive tract, particularly the stomach, and large and small intestines. Viral and bacterial gastroenteritis are intestinal infections associated with symptoms of diarrhea , abdominal cramps, nausea , and vomiting .")
                 speak("Gastroenteritis is an inflammation of the digestive tract, particularly the stomach, and large and small intestines. Viral and bacterial gastroenteritis are intestinal infections associated with symptoms of diarrhea , abdominal cramps, nausea , and vomiting .")
                 print("the precautions to Gastroenteritis is to stop eating solid food for while, try taking small sips of water, rest, ease back into eating")
                 speak("the precautions to Gastroenteritis is to stop eating solid food for while, try taking small sips of water, rest, ease back into eating") 

             elif predict_disease == [11]:
                 print("the disease you are suffering with is Osteoarthristis")
                 speak("the disease you are suffering with is Osteoarthristis")
                 print("Osteoarthritis is the most common form of arthritis, affecting millions of people worldwide. It occurs when the protective cartilage that cushions the ends of your bones wears down over time.")
                 speak("Osteoarthritis is the most common form of arthritis, affecting millions of people worldwide. It occurs when the protective cartilage that cushions the ends of your bones wears down over time.")
                 print("the precautions to Osteoarthristis is to acetaminophen, consult nearest hospital	follow up, salt baths")
                 speak("the precautions to Osteoarthristis is to acetaminophen, consult nearest hospital	follow up, salt baths") 

             else :
                 print(predict_disease)
                 speak(predict_disease)

else :                                                                               
    print("access denied")
    speak("access denied")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-b68d779d738e> in <module>
# ----> 1 speak("hello my name is proxy. i am your fitness advisor")
#       2 speak("enter your username")
#       3 x = input("enter your username : ")
#       4 speak("enter your password")
#       5 y = input("enter your password : ")
#
# NameError: name 'speak' is not defined

# %%
 
 X = df.iloc[:,0:3]
 y = df.iloc[:,3]
 X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 0, test_size = 0.5)

# %%
sc_X = StandardScaler()
X_train = sc_X.fit_transform(X_train)
X_test = sc_X.transform(X_test)

# %%
classifier = KNeighborsClassifier(n_neighbors=1, p=2, metric='euclidean')
classifier.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(metric='euclidean', n_neighbors=1)

# %%
y_pred = classifier.predict(X_train)
y_pred
# Out:
# array([18, 19, 14, 14, 17], dtype=int64)

# %%
print(accuracy_score(y_train, y_pred))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-2b29c6d2724f> in <module>
# ----> 1 print(accuracy_score(y_train, y_pred))
#
# NameError: name 'y_train' is not defined

# %%
xy
